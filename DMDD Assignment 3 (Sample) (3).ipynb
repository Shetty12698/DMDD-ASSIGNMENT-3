# %% [markdown]
# # DMDD Assignment 3 - Web Scraping, Munging and Cleaning the Data.
# ### Prathamesh Kulkarni - 001560684
# ### Shreyas Shetty - 002752852

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://ai-jobs.net/'

# %%
page = requests.get(url).text

# %%
print(page)
# Out:
# <!doctype html>
# <html class="h-100" lang="en">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/>
# <meta name="description" content="Find jobs and talents in AI, Machine Learning, Data Science and Big Data.">
# <title>Jobs in AI/ML and Big Data | ai-jobs.net</title>
#
# <link rel="stylesheet" href="/static/css/style_ai.min.css?v=1.4.1">
#
# <link rel="stylesheet" href="/static/fa/css/all.min.css?v=5.13.0">
# <link rel="canonical" href="https://ai-jobs.net/">
# <link rel="alternate" type="application/rss+xml" title="ai-jobs.net - Job feed" href="https://ai-jobs.net/feed/">
# <link rel="apple-touch-icon" sizes="57x57" href="/static/img/favicons_ai/apple-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="60x60" href="/static/img/favicons_ai/apple-icon-60x60.png">
# ...

# %%
soup = BeautifulSoup(page,'lxml')

# %%
position = soup.find_all('h2',class_='h4 mb-1')

# %%
print(position)
# Out:
# [<h2 class="h4 mb-1">Director of the Institute for Data Science</h2>, <h2 class="h4 mb-1">Data Science Content Intern (Remote)</h2>, <h2 class="h4 mb-1">Python / PHP Senior Developer for Ambitious Startup</h2>, <h2 class="h4 mb-1">Data Scientist - Research, Development &amp; Construction</h2>, <h2 class="h4 mb-1">Senior Data Engineer</h2>, <h2 class="h4 mb-1">Senior Staff Data Scientist</h2>, <h2 class="h4 mb-1">Lead Data Engineer</h2>, <h2 class="h4 mb-1">Data Integration Developer</h2>, <h2 class="h4 mb-1">Data Analytics Manager</h2>, <h2 class="h4 mb-1">Senior Manager, Data Analytics</h2>, <h2 class="h4 mb-1">Senior Engineering Manager – Maritime Autonomy</h2>, <h2 class="h4 mb-1">Data Scientist</h2>, <h2 class="h4 mb-1">Sr. Data Engineer</h2>, <h2 class="h4 mb-1">Senior Data Scientist for Oil and Gas</h2>, <h2 class="h4 mb-1">Senior Data Scientist, Marketing Analytics</h2>, <h2 class="h4 mb-1">Financial Market Data Analyst</h2>, <h2 class="h4 mb-1">Director of AI Engineering &amp
# ...

# %%
List_position=[]

# %%
for i in position:
    List_position.append(i.text)

# %%
List_position
# Out:
# ['Director of the Institute for Data Science',
#  'Data Science Content Intern (Remote)',
#  'Python / PHP Senior Developer for Ambitious Startup',
#  'Data Scientist - Research, Development & Construction',
#  'Senior Data Engineer',
#  'Senior Staff Data Scientist',
#  'Lead Data Engineer',
#  'Data Integration Developer',
#  'Data Analytics Manager',
#  'Senior Manager, Data Analytics',
#  'Senior Engineering Manager – Maritime Autonomy',
#  'Data Scientist',
#  'Sr. Data Engineer',
#  'Senior Data Scientist for Oil and Gas',
#  'Senior Data Scientist, Marketing Analytics',
#  'Financial Market Data Analyst',
#  'Director of AI Engineering & Data Science',
#  'Cloud Database Reliability Engineer',
#  'Software Engineer, Data Collection',
#  'Data Quality Analyst',
#  'Lead Analyst- Data Engineering',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Scientist (27)',
#  'Senior Data Analyst',
#  'Senior Data Scientist',
#  'Ingénieur Système véhicule autonome H/F',
# ...

# %%
Company = soup.find_all('p',class_='m-0 text-muted job-list-item-company')

# %%
print(Company)
# Out:
# [<p class="m-0 text-muted job-list-item-company">University of Mississippi (Ole Miss)</p>, <p class="m-0 text-muted job-list-item-company">NannyML</p>, <p class="m-0 text-muted job-list-item-company">Beatopia</p>, <p class="m-0 text-muted job-list-item-company">HFR, Inc.</p>, <p class="m-0 text-muted job-list-item-company">The Kraft Heinz Company</p>, <p class="m-0 text-muted job-list-item-company">Freshworks</p>, <p class="m-0 text-muted job-list-item-company">Trafi</p>, <p class="m-0 text-muted job-list-item-company">MorphWorks</p>, <p class="m-0 text-muted job-list-item-company">EngagedMD</p>, <p class="m-0 text-muted job-list-item-company">Western Digital</p>, <p class="m-0 text-muted job-list-item-company">Leidos</p>, <p class="m-0 text-muted job-list-item-company">Autofleet</p>, <p class="m-0 text-muted job-list-item-company">MURAL</p>, <p class="m-0 text-muted job-list-item-company">Ayata</p>, <p class="m-0 text-muted job-list-item-company">Remitly</p>, <p class="m-0 text-mute
# ...

# %%
List_Company=[]

# %%
for i in Company:
    List_Company.append(i.text)

# %%
List_Company
# Out:
# ['University of Mississippi (Ole Miss)',
#  'NannyML',
#  'Beatopia',
#  'HFR, Inc.',
#  'The Kraft Heinz Company',
#  'Freshworks',
#  'Trafi',
#  'MorphWorks',
#  'EngagedMD',
#  'Western Digital',
#  'Leidos',
#  'Autofleet',
#  'MURAL',
#  'Ayata',
#  'Remitly',
#  'Qontigo',
#  'Canopy',
#  'lastminute.com',
#  'Jungle Scout',
#  'Trainline',
#  'WNS Global Services',
#  'IT Concepts Inc.',
#  'Newsela',
#  'EMW, Inc.',
#  'Netcentric',
#  'Axiom',
#  'Segula Technologies',
#  'Capco',
#  'Adevinta',
#  'The Kraft Heinz Company',
#  'Ample Insight Inc.',
#  'EMW, Inc.',
#  'SpaceX',
#  'Truelogic Software',
#  'Azenia',
#  'Ample Insight Inc.',
#  'Muddy Machines',
#  'Charger Logistics Inc',
#  'Janus Health',
#  'Ample Insight Inc.',
#  'Hugging Face',
#  'EMW, Inc.',
#  'Katalon',
#  'Catalyst',
#  'DoubleVerify',
#  'Dun & Bradstreet',
#  'Mitsubishi Electric Research Labs',
#  'Axiom',
#  'INAIT',
#  'Sutherland',
#  'Capco',
#  'Ample Insight Inc.',
#  'Barbaricum',
# ...

# %%
Jobtype = soup.find_all('span',class_='badge badge-secondary badge-pill my-md-1')

# %%
print(Jobtype)
# Out:
# [<span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Internship</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>, <span class="badge badge-secondary badge-pill m
# ...

# %%
List_Jobtype=[]

# %%
for i in Jobtype:
    List_Jobtype.append(i.text)

# %%
List_Jobtype
# Out:
# ['Full Time',
#  'Internship',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Internship',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Contract',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Full Time',
#  'Contract',
#  'Full Time',
#  'Full Time',
#  'Full Time',
# ...

# %%
Location = soup.find_all('span',class_='d-none d-md-block text-break job-list-item-location')

# %%
print(Location)
# Out:
# [<span class="d-none d-md-block text-break job-list-item-location">Oxford, MS</span>, <span class="d-none d-md-block text-break job-list-item-location">Remote</span>, <span class="d-none d-md-block text-break job-list-item-location">Remote, EU</span>, <span class="d-none d-md-block text-break job-list-item-location">Remote, Hybrid Available (Chicago)</span>, <span class="d-none d-md-block text-break job-list-item-location">Remote</span>, <span class="d-none d-md-block text-break job-list-item-location">Bengaluru, India</span>, <span class="d-none d-md-block text-break job-list-item-location">Vilnius, Vilnius County, Lithuania</span>, <span class="d-none d-md-block text-break job-list-item-location">Reston, Virginia, United States - Remote</span>, <span class="d-none d-md-block text-break job-list-item-location">Remote</span>, <span class="d-none d-md-block text-break job-list-item-location">Batu Kawan, Malaysia</span>, <span class="d-none d-md-block text-break job-list-item-location"
# ...

# %%
List_location=[]

# %%
for i in Location:
    List_location.append(i.text)

# %%
List_location
# Out:
# ['Oxford, MS',
#  'Remote',
#  'Remote, EU',
#  'Remote, Hybrid Available (Chicago)',
#  'Remote',
#  'Bengaluru, India',
#  'Vilnius, Vilnius County, Lithuania',
#  'Reston, Virginia, United States - Remote',
#  'Remote',
#  'Batu Kawan, Malaysia',
#  'Canberra, Australia',
#  'Tel Aviv-Yafo, Tel Aviv District, Israel',
#  'Latin America (Remote)',
#  'Houston, Texas, United States - Remote',
#  'Seattle, WA',
#  'Buenos Aires, Buenos Aires, Argentina',
#  'London, England, United Kingdom',
#  'Chiasso, Switzerland',
#  'Remote - US',
#  'Edinburgh',
#  'Bengaluru, India',
#  'Woodlawn, Maryland, United States',
#  'Remote',
#  'Norfolk, Virginia, United States',
#  'Iași, Romania',
#  'Belfast, Northern Ireland, United Kingdom',
#  'Courbevoie, France',
#  'India - Pune',
#  'Berlin, Germany',
#  'Remote',
#  'Toronto, ON, Canada',
#  'Norfolk, Virginia, United States',
#  'Hawthorne, CA, United States',
#  'Remote, anywhere in LATAM',
#  'Nairobi, Nairobi, Kenya',
# ...

# %%
Level = soup.find_all('span',class_='badge badge-info badge-pill my-md-1 d-md-none')

# %%
print(Level)
# Out:
# [<span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>, <span class="badge badg
# ...

# %%
List_Level=[]

# %%
for i in Level:
    List_Level.append(i.text)

# %%
List_Level
# Out:
# ['Executive',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Executive',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Executive',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Executive',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Executive',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Entry',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Executive',
#  'Entry',
#  'Mid',
#  'Senior',
#  'Mid',
# ...

# %%
len(List_Company)
# Out:
# 100

# %%
len(List_Jobtype)
# Out:
# 104

# %%
len(List_location)
# Out:
# 100

# %%
len(List_Level)
# Out:
# 97

# %%
for i in range(3):
    List_Level.append("null")

# %%
List_Level
# Out:
# ['Executive',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Executive',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Executive',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Executive',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Executive',
#  'Senior',
#  'Senior',
#  'Entry',
#  'Senior',
#  'Entry',
#  'Mid',
#  'Senior',
#  'Mid',
#  'Entry',
#  'Senior',
#  'Senior',
#  'Senior',
#  'Mid',
#  'Mid',
#  'Senior',
#  'Entry',
#  'Executive',
# ...

# %%
len(List_Level)
# Out:
# 100

# %%
for i in range(4):
    List_Jobtype.pop(-4)

# %%
len(List_Jobtype)
# Out:
# 100

# %%
Data={'Company':List_Company,'Jobtype':List_Jobtype,'Location':List_location,'Level':List_Level}

# %%
df=pd.DataFrame(Data)

# %%
df
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
len(List_Company)
# Out:
# 100

# %%
len(List_position)
# Out:
# 100

# %%
len(List_location)
# Out:
# 100

# %%
len(List_Level)
# Out:
# 100

# %%
for i in range(3):
    List_Level.append("null")

# %%
List_Level

# %%
for i in range(3):
    List_Jobtype.append("null")

# %%
for i in range(3):
    List_Jobtype.pop(-3)

# %%
for i in range(3):
    List_Level.pop(-3)

# %%
df1= df.to_csv('InitialScraping.csv')

# %% [markdown]
# ## Scrapping from Dataset (1)

# %%
df2 = pd.read_csv("DataScienceJobs.csv")

# %%
df3 = df2.iloc[:-980, :]

# %%
df4 = pd.concat([df,df3], axis = 1)

# %%
df4
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
df5 = df4.drop(['location'], axis = 1)

# %%
df5
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
df6 = df5.fillna(0)

# %%
df6
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
df6
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
df6 ['Level'] = df6['Level'].str.replace('null',' ')

# %%
df6
# Out:
#                                  Company     Jobtype  \
# 0   University of Mississippi (Ole Miss)   Full Time
# 1                                NannyML  Internship
# 2                               Beatopia   Full Time
# 3                              HFR, Inc.   Full Time
# 4                The Kraft Heinz Company   Full Time
# ..                                   ...         ...
# 95                           METRO/MAKRO   Full Time
# 96                          NBCUniversal   Full Time
# 97                       Publicis Groupe   Full Time
# 98                                 iland   Full Time
# 99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# 2                           Remote, EU     Senior
# 3   Remote, Hybrid Available (Chicago)     Senior
# 4                               Remote     Senior
# ...

# %%
df7 = df6.to_csv('DMDD_ASSIGNMENT3.csv')

# %% [markdown]
# ## Scraping From Web Page 2

# %%
url = 'https://ai-jobs.net/?cat=5&key=&exp='
page = requests.get(url).text
print(page)
# Out:
# <!doctype html>
# <html class="h-100" lang="en">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1"/>
# <meta name="description" content="Find jobs and talents in AI, Machine Learning, Data Science and Big Data.">
# <title>Jobs in AI/ML and Big Data | ai-jobs.net</title>
#
# <link rel="stylesheet" href="/static/css/style_ai.min.css?v=1.4.1">
#
# <link rel="stylesheet" href="/static/fa/css/all.min.css?v=5.13.0">
# <link rel="canonical" href="https://ai-jobs.net/">
# <link rel="alternate" type="application/rss+xml" title="ai-jobs.net - Job feed" href="https://ai-jobs.net/feed/">
# <link rel="apple-touch-icon" sizes="57x57" href="/static/img/favicons_ai/apple-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="60x60" href="/static/img/favicons_ai/apple-icon-60x60.png">
# ...

# %%
soup = BeautifulSoup(page,'lxml')

# %%
List_Position=[]

# %%
header = soup.find_all('h2',class_='h4 mb-1')
for i in header:
    List_Position.append(i.text)
    (List_Position)

# %%
print(List_Position)
# Out:
# ['Mid Machine Learning Engineer', 'Robotics Software Engineer (Deep Learning)', 'ML Ops Engineer', 'Cloud Machine Learning Engineer - EMEA remote', 'Internship: Metasurfaces for machine vision', 'Reinforcement Learning Specialist', 'Data Scientist - Machine Learning (remote)', 'Senior Machine Learning Software Engineer', 'Machine Learning Engineer', 'Research Fellow, Machine Learning, Small Molecule Drug Design', 'Machine Learning/Computer Vision Engineer Intern', 'Machine Learning Engineer - User Growth', 'Staff Machine Learning Engineer', 'Machine Learning Staff Engineer', 'Machine Learning Engineer, Square Financial Services', 'Machine Learning Engineer - Recommendation (JPN)', 'Machine Learning Intern (Summer 2023)', 'Machine Learning Engineer - II', 'Machine Learning Engineer-Recommendation', 'Internship: Quantum Machine Learning', '⚙️Software Engineer - Machine Learning', 'Internship: Machine Learning for Electric Design Automation', 'Internship: Robust, Private, and Efficient 
# ...

# %%
List_Company = []

# %%
header = soup.find_all('p',class_='m-0 text-muted job-list-item-company')
for i in header:
    List_Company.append(i.text)
    (List_Company)

# %%
print(List_Company)
# Out:
# ['Azenia', 'Muddy Machines', 'Janus Health', 'Hugging Face', 'Mitsubishi Electric Research Labs', 'INAIT', 'Ample Insight Inc.', 'Dropbox', 'Fynd', 'Biogen', 'Norbert Health', 'Spotify', 'Coupang', 'SumUp', 'Block', 'CTW', 'Dropbox', 'Helpshift', 'CTW', 'Mitsubishi Electric Research Labs', 'Infinitus', 'Mitsubishi Electric Research Labs', 'Mitsubishi Electric Research Labs', 'Wayfair Inc.', 'Logikcull', 'Instacart', 'Novetta', 'Kinaxis', 'Spotify', 'BEUMER Group', 'HRL Laboratories', 'Stellar Cyber', 'Novetta', 'Testlio', 'StepStone Group', 'Faire Wholesale, Inc.', 'Shield AI', 'Wayfair Inc.', 'Charger Logistics Inc', 'Sanctuary AI', 'Bosch Group', 'Publicis Groupe', 'GoCardless', 'Course Hero', 'Instacart', 'Rubrik', 'Kinaxis', 'DoorDash', 'Hugging Face', 'Nextdoor', 'Rackner', 'Lucid Motors', 'Oportun', 'Lucid Motors', 'Hugging Face', 'Fyusion, Inc.', 'Bosch Group', 'Hugging Face', 'OPPO Research Center', 'Uni Systems', 'Mercedes-Benz R&D North America', 'Lucid Motors', 'Allegro', 
# ...

# %%
List_Jobtype = []

# %%
header = soup.find_all('span',class_='badge badge-secondary badge-pill my-md-1')
for i in header:
    List_Jobtype.append(i.text)
    (List_Jobtype)

# %%
print(List_Jobtype)
# Out:
# ['Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Contract', 'Full Time', 'Full Time', 'Full Time', 'Temporary', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Internship', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Internship', 'Internship', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Internship', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Internship', 'Full Time', 'Full Time', 'Full Time', 'Full Ti
# ...

# %%
List_Location = []

# %%
header = soup.find_all('span',class_='d-none d-md-block text-break job-list-item-location')
for i in header:
    List_Location.append(i.text)
    (List_Location)

# %%
print(List_Location)
# Out:
# ['Nairobi, Nairobi, Kenya', 'Hayes, England, United Kingdom', 'United States - Remote', 'France - Remote', 'Cambridge, Massachusetts, United States', 'Lausanne, Vaud, Switzerland', 'Toronto, ON, Canada', 'Remote - US; Remote - Canada', 'Ahmedabad', 'Cambridge, MA, United States', 'Paris, FR', 'New York City', 'Mountain View, USA', 'Berlin, Germany', 'San Francisco, CA, United States', 'Roppongi, Tokyo, Japan', 'Remote - US; Remote - Canada', 'Pune', 'Roppongi, Tokyo, Japan', 'Cambridge, Massachusetts, United States', 'San Francisco, CA / New York City, …', 'Cambridge, Massachusetts, United States', 'Cambridge, Massachusetts, United States', 'Berlin, DE', 'United States', 'Remote - United States', 'Arlington, VA', 'Canada', 'New York City', 'Aarhus, Denmark', 'Calabasas, CA', 'United States - Remote', 'Arlington, VA', 'Remote in EMEA', 'London, United Kingdom', 'Canada', 'San Diego Metro Area', 'Berlin, DE', 'Brampton, Ontario, Canada', 'Vancouver, BC', 'Stuttgart, Germany', 'Chicago,
# ...

# %%
Data={'Company':List_Company,'Position':List_Position,'Jobtype':List_Jobtype,'Level;':List_Level}

# %%
df8 = pd.DataFrame(Data)

# %%
df8
# Out:
#                               Company  \
# 0                              Azenia
# 1                      Muddy Machines
# 2                        Janus Health
# 3                        Hugging Face
# 4   Mitsubishi Electric Research Labs
# ..                                ...
# 95              Charger Logistics Inc
# 96                       SurveyMonkey
# 97                             Talend
# 98                       Wayfair Inc.
# 99       Charles River Analytics Inc.
#
#                                              Position     Jobtype     Level;
# 0                       Mid Machine Learning Engineer   Full Time  Executive
# 1          Robotics Software Engineer (Deep Learning)   Full Time      Entry
# 2                                     ML Ops Engineer   Full Time     Senior
# 3       Cloud Machine Learning Engineer - EMEA remote   Full Time     Senior
# 4         Internship: Metasurfaces for machine vision  Internship     Senior
# ...

# %%
len(List_Position)
# Out:
# 100

# %%
len(List_Company)
# Out:
# 100

# %%
len(List_Jobtype)
# Out:
# 104

# %%
len(List_Level)
# Out:
# 100

# %%
for i in range(4):
    List_Jobtype.pop(-4)

# %%
df9= df8.to_csv('WEBSC_2.csv')

# %% [markdown]
# ## Web Scraping From Dataset ( 2 )

# %%
df10 = pd.read_csv("DS Salaries.csv")

# %%
df10
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df10.tail(100)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 145     2021e               EX              FT   Data Science Consultant
# 146     2021e               SE              FT   Data Analytics Engineer
# 147     2021e               MI              FT             Data Engineer
# 148      2020               EN              FT            Data Scientist
# 149      2020               MI              FT         Lead Data Analyst
# ..        ...              ...             ...                       ...
# 240      2020               SE              FT            Data Scientist
# 241     2021e               MI              FT  Principal Data Scientist
# 242      2020               EN              FT            Data Scientist
# 243      2020               EN              CT     Business Data Analyst
# 244     2021e               SE              FT      Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df11 = df10.drop(['remote_ratio'], axis = 1)

# %%
df10
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df12 = df11.drop(['company_size'], axis = 1)

# %%
df12
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df13 = df12.replace("FT","Full Time",regex = True)

# %%
df13
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN       Full Time    Data Science Consultant
# 1        2020               SE       Full Time             Data Scientist
# 2       2021e               EX       Full Time       Head of Data Science
# 3       2021e               EX       Full Time               Head of Data
# 4       2021e               EN       Full Time  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE       Full Time             Data Scientist
# 241     2021e               MI       Full Time   Principal Data Scientist
# 242      2020               EN       Full Time             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE       Full Time       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df14 = df13.replace("EN"," Entry Level ",regex = True)

# %%
df14
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e     Entry Level        Full Time    Data Science Consultant
# 1        2020               SE       Full Time             Data Scientist
# 2       2021e               EX       Full Time       Head of Data Science
# 3       2021e               EX       Full Time               Head of Data
# 4       2021e     Entry Level        Full Time  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE       Full Time             Data Scientist
# 241     2021e               MI       Full Time   Principal Data Scientist
# 242      2020     Entry Level        Full Time             Data Scientist
# 243      2020     Entry Level               CT      Business Data Analyst
# 244     2021e               SE       Full Time       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  \
# ...

# %%
df15 = df14.replace("EX"," Executive Level ",regex = True)

# %%
df15
# Out:
#     work_year   experience_level employment_type                  job_title  \
# 0       2021e       Entry Level        Full Time    Data Science Consultant
# 1        2020                 SE       Full Time             Data Scientist
# 2       2021e   Executive Level        Full Time       Head of Data Science
# 3       2021e   Executive Level        Full Time               Head of Data
# 4       2021e       Entry Level        Full Time  Machine Learning Engineer
# ..        ...                ...             ...                        ...
# 240      2020                 SE       Full Time             Data Scientist
# 241     2021e                 MI       Full Time   Principal Data Scientist
# 242      2020       Entry Level        Full Time             Data Scientist
# 243      2020       Entry Level               CT      Business Data Analyst
# 244     2021e                 SE       Full Time       Data Science Manager
#
# ...

# %%
df16 = df15.replace("SE"," Senior Executive",regex = True)

# %%
df16
# Out:
#     work_year   experience_level employment_type                  job_title  \
# 0       2021e       Entry Level        Full Time    Data Science Consultant
# 1        2020   Senior Executive       Full Time             Data Scientist
# 2       2021e   Executive Level        Full Time       Head of Data Science
# 3       2021e   Executive Level        Full Time               Head of Data
# 4       2021e       Entry Level        Full Time  Machine Learning Engineer
# ..        ...                ...             ...                        ...
# 240      2020   Senior Executive       Full Time             Data Scientist
# 241     2021e                 MI       Full Time   Principal Data Scientist
# 242      2020       Entry Level        Full Time             Data Scientist
# 243      2020       Entry Level               CT      Business Data Analyst
# 244     2021e   Senior Executive       Full Time       Data Science Manager
#
# ...

# %%
df17 = df16.replace("2021e"," 2021",regex = True)

# %%
df17
# Out:
#     work_year   experience_level employment_type                  job_title  \
# 0        2021       Entry Level        Full Time    Data Science Consultant
# 1        2020   Senior Executive       Full Time             Data Scientist
# 2        2021   Executive Level        Full Time       Head of Data Science
# 3        2021   Executive Level        Full Time               Head of Data
# 4        2021       Entry Level        Full Time  Machine Learning Engineer
# ..        ...                ...             ...                        ...
# 240      2020   Senior Executive       Full Time             Data Scientist
# 241      2021                 MI       Full Time   Principal Data Scientist
# 242      2020       Entry Level        Full Time             Data Scientist
# 243      2020       Entry Level               CT      Business Data Analyst
# 244      2021   Senior Executive       Full Time       Data Science Manager
#
# ...

# %%
df18 = df17.replace("MI"," Managerial Role ",regex = True)

# %%
df18
# Out:
#     work_year   experience_level employment_type                  job_title  \
# 0        2021       Entry Level        Full Time    Data Science Consultant
# 1        2020   Senior Executive       Full Time             Data Scientist
# 2        2021   Executive Level        Full Time       Head of Data Science
# 3        2021   Executive Level        Full Time               Head of Data
# 4        2021       Entry Level        Full Time  Machine Learning Engineer
# ..        ...                ...             ...                        ...
# 240      2020   Senior Executive       Full Time             Data Scientist
# 241      2021   Managerial Role        Full Time   Principal Data Scientist
# 242      2020       Entry Level        Full Time             Data Scientist
# 243      2020       Entry Level               CT      Business Data Analyst
# 244      2021   Senior Executive       Full Time       Data Science Manager
#
# ...

# %%
df19 = df18.replace("CT"," Career Trainee ",regex = True)

# %%
df19
# Out:
#     work_year   experience_level   employment_type                  job_title  \
# 0        2021       Entry Level          Full Time    Data Science Consultant
# 1        2020   Senior Executive         Full Time             Data Scientist
# 2        2021   Executive Level          Full Time       Head of Data Science
# 3        2021   Executive Level          Full Time               Head of Data
# 4        2021       Entry Level          Full Time  Machine Learning Engineer
# ..        ...                ...               ...                        ...
# 240      2020   Senior Executive         Full Time             Data Scientist
# 241      2021   Managerial Role          Full Time   Principal Data Scientist
# 242      2020       Entry Level          Full Time             Data Scientist
# 243      2020       Entry Level    Career Trainee       Business Data Analyst
# 244      2021   Senior Executive         Full Time       Data Science Manager
#
# ...

# %%
df20= df19.to_csv('Scraping3.csv')

# %%
import sqlite3
conn = sqlite3.connect('Web_Scraping')

# %%
df21 = pd.read_csv("InitialScraping.csv")

# %%
df22 = df21.to_sql('InitialScraping_1',con=conn,index=False, if_exists='replace')

# %%
df22
# Out:
# 100

# %%
df23 = pd.read_csv("DMDD_Assignment3.csv")

# %%
df24 = df23.to_sql('DMDD_ASSIGNMENT3',con=conn,index=False, if_exists='replace')

# %%
df24
# Out:
# 100

# %%
df25 = pd.read_csv("WEBSC_2.csv")

# %%
df26 = df25.to_sql('WEBSC_2_1',con=conn,index=False, if_exists='replace')

# %%
df26
# Out:
# 100

# %%
df27 = pd.read_csv("Scraping3.csv")

# %%
df28 = df27.to_sql('Scraping3_1',con=conn,index=False, if_exists='replace')

# %%
df28
# Out:
# 245

# %%
df29 = pd.read_sql_query("select * from InitialScraping_1", con = conn )

# %%
df29
# Out:
#     Unnamed: 0                               Company     Jobtype  \
# 0            0  University of Mississippi (Ole Miss)   Full Time
# 1            1                               NannyML  Internship
# 2            2                              Beatopia   Full Time
# 3            3                             HFR, Inc.   Full Time
# 4            4               The Kraft Heinz Company   Full Time
# ..         ...                                   ...         ...
# 95          95                           METRO/MAKRO   Full Time
# 96          96                          NBCUniversal   Full Time
# 97          97                       Publicis Groupe   Full Time
# 98          98                                 iland   Full Time
# 99          99                         ZigZag Global   Full Time
#
#                               Location      Level
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# ...

# %%
df30 = pd.read_sql_query("select * from DMDD_Assignment3", con = conn )

# %%
df30
# Out:
#     Unnamed: 0                               Company     Jobtype  \
# 0            0  University of Mississippi (Ole Miss)   Full Time
# 1            1                               NannyML  Internship
# 2            2                              Beatopia   Full Time
# 3            3                             HFR, Inc.   Full Time
# 4            4               The Kraft Heinz Company   Full Time
# ..         ...                                   ...         ...
# 95          95                           METRO/MAKRO   Full Time
# 96          96                          NBCUniversal   Full Time
# 97          97                       Publicis Groupe   Full Time
# 98          98                                 iland   Full Time
# 99          99                         ZigZag Global   Full Time
#
#                               Location      Level  \
# 0                           Oxford, MS  Executive
# 1                               Remote      Entry
# ...

# %%
df31 = pd.read_sql_query("select * from WEBSC_2_1", con = conn )

# %%
df31
# Out:
#     Unnamed: 0                            Company  \
# 0            0                             Azenia
# 1            1                     Muddy Machines
# 2            2                       Janus Health
# 3            3                       Hugging Face
# 4            4  Mitsubishi Electric Research Labs
# ..         ...                                ...
# 95          95              Charger Logistics Inc
# 96          96                       SurveyMonkey
# 97          97                             Talend
# 98          98                       Wayfair Inc.
# 99          99       Charles River Analytics Inc.
#
#                                              Position     Jobtype     Level;
# 0                       Mid Machine Learning Engineer   Full Time  Executive
# 1          Robotics Software Engineer (Deep Learning)   Full Time      Entry
# 2                                     ML Ops Engineer   Full Time     Senior
# ...

# %%
df32 = pd.read_sql_query("select * from Scraping3_1", con = conn )

# %%
df32
# Out:
#      Unnamed: 0  work_year   experience_level   employment_type  \
# 0             0       2021       Entry Level          Full Time
# 1             1       2020   Senior Executive         Full Time
# 2             2       2021   Executive Level          Full Time
# 3             3       2021   Executive Level          Full Time
# 4             4       2021       Entry Level          Full Time
# ..          ...        ...                ...               ...
# 240         240       2020   Senior Executive         Full Time
# 241         241       2021   Managerial Role          Full Time
# 242         242       2020       Entry Level          Full Time
# 243         243       2020       Entry Level    Career Trainee
# 244         244       2021   Senior Executive         Full Time
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0      Data Science Consultant    54000             EUR          64369
# ...

# %% [markdown]
# ## Use Cases from previous assignments
#
# 1) Use Case: Display tweets searched by a keyword "Full Time".
# Description: User can view tweets containing the job keyword
#
# Actor: User
#
# Precondition: When a user wants to search tweets using a specific keyword.
#
# Steps: 'Select * from InitialScraping_1 where Tweet like "%Full Time%" ', con = conn
#
# Actor action: User views tweets containing keyword Job.
#
# System Responses: The list of tweets with the keyword Job is displayed.
#
# Post Condition:User successfully views the tweets with the keyword Job.
#
# Alternate Path: The are no tweets with keyword Job available to display.
#
# Error: Tweets searched by keyword "Job" do not exist.

# %%
import matplotlib as plt
import seaborn as sns
import sys
from pylab import *

# %% [markdown]
# ## New Use Cases
#
# 1) Use Case: Display tweets searched by company and Job Type.
# Description: User can view data containing company and Job Type.
#
# Actor: User
#
# Precondition: When a user wants to search data using company and Job Type.
#
# Steps:('select c.Company,o.Jobtype from InitialScraping_1 c inner join DMDD_Assignment3 o on c.Company = o.Company',con = conn )
#
# Actor action: User views data containing company and Job Type.
#
# System Responses: The list of data with tcompany and Job Type are displayed.
#
# Post Condition:User successfully views the data with company and Job Type.
#
# Alternate Path: There is no data with keyword Job available to display.
#
# Error: Data searched by company and Job Type do not exist.
#
#
# 2) Use Case: Display data grouped by level.
# Description: User can view data containing Level and Job Type grouped by Level.
#
# Actor: User
#
# Precondition: When a user wants to search containing Level and Job Type grouped by Level.
#
# Steps:df34 = ('select c.Jobtype,o.Level from InitialScraping_1 c left join DMDD_Assignment3 o on c.Company= o.Company ORDER BY c.Level', con = conn )
#
# Actor action: User views data containing Level and Job Type grouped by Level.
#
# System Responses: The list of data containing Level and Job Type grouped by Level are displayed.
#
# Post Condition:User successfully views the data containing Level and Job Type grouped by Level.
#
# Alternate Path: There is no data containing Level and Job Type grouped by Level available to display.
#
# Error: Data data containing Level and Job Type grouped by Level do not exist.
#
#
# 3) Use Case: Display data containing job type and location grouped by location .
# Description: User can view data containing job type and location grouped by location.
#
# Actor: User
#
# Precondition: When a user wants to search data containing job type and location grouped by location.
#
# Steps: ('select c.Jobtype,o.Location from InitialScraping_1 c right join DMDD_Assignment3 o on c.Company= o.Company ORDER BY c.Location',con = conn )
#
# Actor action: User views data containing job type and location grouped by location.
#
# System Responses: The list of data containing containing job type and location grouped by location are displayed.
#
# Post Condition:User successfully views the data containing job type and location grouped by location.
#
# Alternate Path: There is no data containing containing job type and location grouped by location available to display.
#
# Error: Data data containing job type and location grouped by location do not exist.
#
#
# 4) Use Case: Display data containing Company and job type grouped by Company.
# Description: User can view data containing Company and job type grouped by Company.
#
# Actor: User
#
# Precondition: When a user wants to search data containing Company and job type grouped by Company.
#
# Steps: ('select c.Company,o.Jobtype from InitialScraping_1 c right join DMDD_Assignment3 o on c.Company= o.Company ORDER BY c.Company',con = conn )
#
# Actor action: User views data containing Company and job type grouped by Company.
#
# System Responses: The list of data containing Company and job type grouped by Company.
#
# Post Condition:User successfully views the data containing Company and job type grouped by Company.
#
# Alternate Path: There is no data containing containing Company and job type grouped by Company available to display.
#
# Error: Data data containing Company and job type grouped by Company do not exist.
#
#
# 5) Use Case: Display data containing Company and Level.
# Description: User can view data containing Company and Level.
#
# Actor: User
#
# Precondition: When a user wants to search data containing Company and Level.
#
# Steps:('select c.Level,c1.Company from InitialScraping_1 c, InitialScraping_1 c1 where  c.Jobtype= c1.Jobtype',con = conn )
#
# Actor action: User views data containing Company and Level.
#
# System Responses: The list of data containing Company and Level.
#
# Post Condition:User successfully views the data containing Company and Level.
#
# Alternate Path: There is no data containing Company and Level to display.
#
# Error: Data data containing Company and Level do not exist.
#
#
# 6) Use Case: Display data containing Job Title and Salary .
# Description: User can view data containing Job Title and Salary .
#
# Actor: User
#
# Precondition: When a user wants to search data containing Job Title and Salary .
#
# Steps:('select c.job_title,c1.salary from Scraping3_1 c, Scraping3_1 c1 where  c.salary= c1.salary',con = conn )
#
# Actor action: User views data containing Job Title and Salary .
#
# System Responses: The list of data containing Job Title and Salary .
#
# Post Condition:User successfully views the data containing Job Title and Salary .
#
# Alternate Path: There is no data containing Job Title and Salary  to display.
#
# Error: Data data containing Job Title and Salary do not exist.
#
#
# 7) Use Case: Display data containing Position, Company and Jobtype .
# Description: User can view data containing Position, Company and Jobtype.
#
# Actor: User
#
# Precondition: When a user wants to search data containing Position, Company and Jobtype .
#
# Steps:'select c.Position,c1.Company, c1.Jobtype from WEBSC_2_1 c, WEBSC_2_1 c1 where  c.Position = c1.Position ',con = conn )
#
# Actor action: User views data containing Position, Company and Jobtype.
#
# System Responses: The list of data containing Position, Company and Jobtype.
#
# Post Condition:User successfully views the data containing Position, Company and Jobtype .
#
# Alternate Path: There is no data containing Position, Company and Jobtypeto display.
#
# Error: Data data containing Position, Company and Jobtypedo not exist.
#
#
#
# 8) Use Case: Display data containing Summary and Jobtype .
# Description: User can view data containing Summary and Jobtype.
#
# Actor: User
#
# Precondition: When a user wants to search data containing Summary and Jobtype .
#
# Steps:('select c.Jobtype,o.Summary from InitialScraping_1 c left join DMDD_Assignment3 o on c.Company= o.Company',con = conn )
#
# Actor action: User views data containing Summary and Jobtype .
#
# System Responses: The list of data containing Summary and Jobtype .
#
# Post Condition:User successfully views the data containing Summary and Jobtype  .
#
# Alternate Path: There is no data containing Summary and Jobtype to display.
#
# Error: Data data containing Summary and Jobtype do not exist.
#
#
# 9) Use Case: Display data containing Experience Level, Employment Type and Employee Residence .
# Description: User can view data Experience Level, Employment Type and Employee Residence .
#
# Actor: User
#
# Precondition: When a user wants to search data containing Experience Level, Employment Type and Employee Residence  .
#
# Steps:('select c.experience_level,c1.employment_type, c1.employee_residence from Scraping3_1 c, Scraping3_1 c1 where  c.salary= c1.salary',con = conn )
#
# Actor action: User views data containing Experience Level, Employment Type and Employee Residence .
#
# System Responses: The list of data containing Experience Level, Employment Type and Employee Residence  .
#
# Post Condition:User successfully views the data containing Experience Level, Employment Type and Employee Residence   .
#
# Alternate Path: There is no data containing Experience Level, Employment Type and Employee Residence to display.
#
# Error: Data data containing Experience Level, Employment Type and Employee Residence  do not exist.
#
#
# 10) Use Case: Display data containing Company and Salary.
# Description: User can view data containing Company and Salary .
#
# Actor: User
#
# Precondition: When a user wants to search data containing Company and Salary.
#
# Steps:('select c.Company,o.Salary from InitialScraping_1 c right join DMDD_Assignment3 o on c.Company= o.Company',con = conn )
# Actor action: User views data containing Company and Salary.
#
# System Responses: The list of data containing Company and Salary.
#
# Post Condition:User successfully views the data containing Company and Salary.
#
# Alternate Path: There is no data containing Company and Salary to display.
#
# Error: Data data containing Company and Salary do not exist.

# %%
df33 = pd.read_sql_query('select c.Company,o.Jobtype from InitialScraping_1 c inner join DMDD_Assignment3 o on c.Company = o.Company',con = conn )

# %%
df33
# Out:
#                                   Company     Jobtype
# 0    University of Mississippi (Ole Miss)   Full Time
# 1                                 NannyML  Internship
# 2                                Beatopia   Full Time
# 3                               HFR, Inc.   Full Time
# 4                 The Kraft Heinz Company   Full Time
# ..                                    ...         ...
# 181                       Publicis Groupe   Full Time
# 182                       Publicis Groupe   Full Time
# 183                       Publicis Groupe  Internship
# 184                                 iland   Full Time
# 185                         ZigZag Global   Full Time
#
# [186 rows x 2 columns]

# %%
df34 = pd.read_sql_query('select c.Jobtype,o.Level from InitialScraping_1 c left join DMDD_Assignment3 o on c.Company= o.Company ORDER BY c.Level', con = conn )

# %%
df34
# Out:
#        Jobtype   Level
# 0    Full Time
# 1    Full Time   Entry
# 2    Full Time     Mid
# 3    Full Time  Senior
# 4    Full Time  Senior
# ..         ...     ...
# 181  Full Time  Senior
# 182  Full Time  Senior
# 183  Full Time  Senior
# 184  Full Time  Senior
# 185  Full Time  Senior
#
# [186 rows x 2 columns]

# %%
df35= pd.read_sql_query('select c.Jobtype,o.Location from InitialScraping_1 c right join DMDD_Assignment3 o on c.Company= o.Company ORDER BY c.Location',con = conn )

# %%
df35
# Out:
#         Jobtype                            Location
# 0     Full Time              Amsterdam, Netherlands
# 1     Full Time              Amsterdam, Netherlands
# 2     Full Time              Amsterdam, Netherlands
# 3     Full Time              Amsterdam, Netherlands
# 4     Full Time              Amsterdam, Netherlands
# ..          ...                                 ...
# 181   Full Time              United States - Remote
# 182   Full Time               Vancouver, BC, Canada
# 183   Full Time  Vilnius, Vilnius County, Lithuania
# 184  Internship       Washington, DC, United States
# 185   Full Time   Woodlawn, Maryland, United States
#
# [186 rows x 2 columns]

# %%
df36 = pd.read_sql_query('select c.Jobtype,o.Company from InitialScraping_1 c full outer join DMDD_Assignment3 o on c.Jobtype= o.Jobtype ORDER BY c.COmpany',con = conn )

# %%
df36
# Out:
#         Jobtype                               Company
# 0     Full Time  University of Mississippi (Ole Miss)
# 1     Full Time                              Beatopia
# 2     Full Time                             HFR, Inc.
# 3     Full Time               The Kraft Heinz Company
# 4     Full Time                            Freshworks
# ...         ...                                   ...
# 8851  Full Time                           METRO/MAKRO
# 8852  Full Time                          NBCUniversal
# 8853  Full Time                       Publicis Groupe
# 8854  Full Time                                 iland
# 8855  Full Time                         ZigZag Global
#
# [8856 rows x 2 columns]

# %%
df37 = pd.read_sql_query('select c.Level,c1.Company from InitialScraping_1 c, InitialScraping_1 c1 where  c.Jobtype= c1.Jobtype',con = conn )

# %%
df37
# Out:
#           Level               Company
# 0     Executive           AUTO1 Group
# 1     Executive            AccorCorpo
# 2     Executive              Adevinta
# 3     Executive    Ample Insight Inc.
# 4     Executive    Ample Insight Inc.
# ...         ...                   ...
# 8851       None       Western Digital
# 8852       None         ZigZag Global
# 8853       None  dentsu international
# 8854       None                 iland
# 8855       None        lastminute.com
#
# [8856 rows x 2 columns]

# %%
df38 = pd.read_sql_query('select c.job_title,c1.salary from Scraping3_1 c, Scraping3_1 c1 where  c.salary= c1.salary',con = conn )

# %%
df38
# Out:
#                    job_title   salary
# 0    Data Science Consultant    54000
# 1    Data Science Consultant    54000
# 2             Data Scientist    60000
# 3             Data Scientist    60000
# 4             Data Scientist    60000
# ..                       ...      ...
# 640    Business Data Analyst   100000
# 641    Business Data Analyst   100000
# 642    Business Data Analyst   100000
# 643    Business Data Analyst   100000
# 644     Data Science Manager  7000000
#
# [645 rows x 2 columns]

# %%
df39 = pd.read_sql_query('select c.experience_level,c1.employment_type, c1.employee_residence from Scraping3_1 c, Scraping3_1 c1 where  c.salary= c1.salary',con = conn )

# %%
df39
# Out:
#       experience_level employment_type employee_residence
# 0         Entry Level        Full Time                 DE
# 1         Entry Level        Full Time                 DE
# 2     Senior Executive              FL                 RU
# 3     Senior Executive       Full Time                 GB
# 4     Senior Executive       Full Time                 GB
# ..                 ...             ...                ...
# 640       Entry Level        Full Time                 JE
# 641       Entry Level        Full Time                 PL
# 642       Entry Level        Full Time                 US
# 643       Entry Level        Full Time                 US
# 644   Senior Executive       Full Time                 IN
#
# [645 rows x 3 columns]

# %%
df40 = pd.read_sql_query('select c.Position,c1.Company, c1.Jobtype from WEBSC_2_1 c, WEBSC_2_1 c1 where  c.Position = c1.Position ',con = conn )

# %%
df40
# Out:
#                                               Position  \
# 0                        Mid Machine Learning Engineer
# 1           Robotics Software Engineer (Deep Learning)
# 2                                      ML Ops Engineer
# 3        Cloud Machine Learning Engineer - EMEA remote
# 4          Internship: Metasurfaces for machine vision
# ..                                                 ...
# 135                          Machine Learning Engineer
# 136              Machine Learning Intern - Summer 2023
# 137                             Stage Machine Learning
# 138           ML Scientist, Wayfair Professional (B2B)
# 139  Software Engineer Co-op - Computer Vision & De...
#
#                                Company     Jobtype
# 0                               Azenia   Full Time
# 1                       Muddy Machines   Full Time
# 2                         Janus Health   Full Time
# 3                         Hugging Face   Full Time
# ...

# %%
df41 = pd.read_sql_query('select c.Jobtype,o.Summary from InitialScraping_1 c left join DMDD_Assignment3 o on c.Company= o.Company',con = conn )

# %%
df41
# Out:
#         Jobtype                                            summary
# 0     Full Time  An artificial intelligence (AI) specialist app...
# 1    Internship  We are seeking highly motivated individuals wi...
# 2     Full Time  We are dedicated to providing quality and effe...
# 3     Full Time  Working on over 18 different browser/os/ mobil...
# 4     Full Time  Total Experience: 6- 8 yrs.\nAutomation Testin...
# ..          ...                                                ...
# 181   Full Time  We engineer business outcomes for Fortune 500 ...
# 182   Full Time  Years of Experience: 13-18 years.\nYou will be...
# 183   Full Time  You will focus on a portfolio of services, too...
# 184   Full Time  We engineer business outcomes for Fortune 500 ...
# 185   Full Time  Through its industry-focused programs, INSAID ...
#
# [186 rows x 2 columns]

# %%
df42= pd.read_sql_query('select c.Company,o.Salary from InitialScraping_1 c right join DMDD_Assignment3 o on c.Company= o.Company',con = conn )

# %%
df42
# Out:
#                                   Company                     salary
# 0    University of Mississippi (Ole Miss)                          0
# 1                                 NannyML                          0
# 2                                Beatopia  ₹15,000 - ₹25,000 a month
# 3                               HFR, Inc.                          0
# 4                 The Kraft Heinz Company                          0
# ..                                    ...                        ...
# 181                       Publicis Groupe                          0
# 182                       Publicis Groupe                          0
# 183                       Publicis Groupe                          0
# 184                                 iland                          0
# 185                         ZigZag Global            ₹15,000 a month
#
# [186 rows x 2 columns]

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(df29)

# %%
corelation = df30.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>
